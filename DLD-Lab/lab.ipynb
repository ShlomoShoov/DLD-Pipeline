# %% [markdown]
# ### Loading Data

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("developer_ai_learning_raw.csv")

# %% [markdown]
# ### Get Know The Data

# %%
df.sample(5)
# Out:
#        ResponseId              Age  YearsCode  \
# 12384       12385  35-44 years old       18.0
# 8350         8351  18-24 years old        4.0
# 16250       16251  35-44 years old       22.0
# 28010       28011  25-34 years old       15.0
# 18242       18243  35-44 years old       20.0
#
#                                     DevType  \
# 12384      Architect, software or solutions
# 8350                  Developer, full-stack
# 16250  Senior executive (C-suite, VP, etc.)
# 28010      Architect, software or solutions
# 18242                   Academic researcher
#
#                                          LearnCodeChoose  \
# 12384  Yes, I am not new to coding but am learning ne...
# 8350   Yes, I am not new to coding but am learning ne...
# 16250  No, I am not new to coding and did not learn n...
# 28010  No, I am not new to coding and did not learn n...
# 18242  Yes, I am not new to coding but am learning ne...
#
#                                                LearnCode  \
# 12384            School (i.e., University, College, etc)
# 8350   Online Courses or Certification (includes all ...
# 16250                                                NaN
# 28010                                                NaN
# 18242  Other online resources (e.g. standard search, ...
#
#                                              LearnCodeAI  \
# 12384  Yes, I learned how to use AI-enabled tools for...
# 8350   Yes, I learned how to use AI-enabled tools req...
# 16250  No, I didn't spend time learning in the past year
# 28010  Yes, I learned how to use AI-enabled tools for...
# 18242  Yes, I learned how to use AI-enabled tools req...
#
#                                               AILearnHow  \
# 12384  Other online resources (e.g. standard search, ...
# 8350   AI CodeGen tools or AI-enabled apps;Technical ...
# 16250                                                NaN
# 28010  Videos (not associated with specific online co...
# 18242  AI CodeGen tools or AI-enabled apps;Technical ...
#
#                                           AISelect  \
# 12384                    Yes, I use AI tools daily
# 8350                     Yes, I use AI tools daily
# 16250  Yes, I use AI tools monthly or infrequently
# 28010                                          NaN
# 18242                    Yes, I use AI tools daily
#
#                             AIAcc          AISent
# 12384              Somewhat trust       Favorable
# 8350               Somewhat trust  Very favorable
# 16250             Highly distrust     Unfavorable
# 28010                         NaN             NaN
# 18242  Neither trust nor distrust       Favorable

# %%
df.shape
# Out:
# (49191, 11)

# %%
df.columns
# Out:
# Index(['ResponseId', 'Age', 'YearsCode', 'DevType', 'LearnCodeChoose',
#        'LearnCode', 'LearnCodeAI', 'AILearnHow', 'AISelect', 'AIAcc',
#        'AISent'],
#       dtype='str')

# %%
for col in df.columns:
    print(f"for col {col} - {len(df[col].unique())} unique values")
# Out:
# for col ResponseId - 49191 unique values
# for col Age - 7 unique values
# for col YearsCode - 79 unique values
# for col DevType - 33 unique values
# for col LearnCodeChoose - 4 unique values
# for col LearnCode - 2768 unique values
# for col LearnCodeAI - 6 unique values
# for col AILearnHow - 1678 unique values
# for col AISelect - 6 unique values
# for col AIAcc - 6 unique values
# for col AISent - 7 unique values

# %%
df.dtypes
# Out:
# ResponseId           int64
# Age                    str
# YearsCode          float64
# DevType                str
# LearnCodeChoose        str
# LearnCode              str
# LearnCodeAI            str
# AILearnHow             str
# AISelect               str
# AIAcc                  str
# AISent                 str
# dtype: object

# %%
df.isna().sum()
# Out:
# ResponseId             0
# Age                    0
# YearsCode           6149
# DevType             5511
# LearnCodeChoose     2333
# LearnCode          15635
# LearnCodeAI         3990
# AILearnHow         20934
# AISelect           15471
# AIAcc              15894
# AISent             15724
# dtype: int64

# %%
dim1 = df.shape[0]
for col in df.columns:
    print(f"For {col} : {df[col].isna().sum()}/{dim1} is null. ({df[col].isna().sum()/dim1*100:2f}%)")
# Out:
# For ResponseId : 0/49191 is null. (0.000000%)
# For Age : 0/49191 is null. (0.000000%)
# For YearsCode : 6149/49191 is null. (12.500254%)
# For DevType : 5511/49191 is null. (11.203269%)
# For LearnCodeChoose : 2333/49191 is null. (4.742737%)
# For LearnCode : 15635/49191 is null. (31.784269%)
# For LearnCodeAI : 3990/49191 is null. (8.111240%)
# For AILearnHow : 20934/49191 is null. (42.556565%)
# For AISelect : 15471/49191 is null. (31.450875%)
# For AIAcc : 15894/49191 is null. (32.310789%)
# For AISent : 15724/49191 is null. (31.965197%)

# %%
f"duplicated cols:{(df.duplicated().sum()/dim1 *100):2f}%"
# Out:
# 'duplicated cols:0.000000%'

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ResponseId, Age, YearsCode, DevType, LearnCodeChoose, LearnCode, LearnCodeAI, AILearnHow, AISelect, AIAcc, AISent]
# Index: []

# %%
df.AISent.unique()
# Out:
# <StringArray>
# [     'Indifferent',        'Favorable',   'Very favorable',
#       'Unfavorable',                nan, 'Very unfavorable',
#            'Unsure']
# Length: 7, dtype: str
